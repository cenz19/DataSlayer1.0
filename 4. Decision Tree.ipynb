# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data = pd.read_csv("preprocessing_dt.csv", index_col=0)
data.head(10)
# Out:
#             Make            Vehicle Class  Engine Size(L)  Cylinders  \
# 0           FOLD  PICKUP TRUCK - STANDARD             3.5        6.0
# 6          GONDA                FULL-SIZE             1.8        4.0
# 7   LAND CRAWLER              SUV - SMALL             2.0        4.0
# 11           BMV               SUBCOMPACT             3.0        6.0
# 12        TOYOTI                  MINIVAN             2.0        4.0
# 17          FOLD           SUV - STANDARD             2.3        4.0
# 21         CHEVO                  COMPACT             1.4        4.0
# 22         GONDA    STATION WAGON - SMALL             3.5        6.0
# 24         ASURA                  COMPACT             2.4        4.0
# 29         LECUS              SUV - SMALL             3.5        6.0
#
#    Transmission Fuel Type  Fuel Consumption City  Fuel Consumption Hwy  \
# 0            A6         X               8.640000              6.140000
# 6           AV7         X               7.520000             19.138279
# 7           AS8         Z               8.238704              2.060000
# 11           M6         Z              19.010000              8.541911
# 12          AS6         X               0.022000              5.300000
# 17          AS6         X               5.020000              7.020000
# 21          AS6         X              10.857763              9.045181
# 22           M6         X              11.614402              8.635579
# 24           M6         Z               0.440000             21.890000
# 29          AS8         X              17.780000              9.328358
#
#     Fuel Consumption Comb  CO2 Emissions(g/km)
# 0                7.514791                306.0
# 6               12.750000                174.0
# 7                5.455537                246.0
# 11              14.306152                236.0
# 12               3.579098                260.0
# 17               5.920000                263.0
# 21               0.100000                130.0
# 22              10.270000                158.0
# 24               0.101000                208.0
# 29               0.140000                259.0

# %%
col_names = ["Engine Size(L)", "Cylinders"]
y_label = ["Fuel Type"]

# %%
df_x = data[col_names]
df_y = data[y_label]

# %%
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=.2, random_state=1)

# %%
clf = DecisionTreeClassifier(max_depth=4, criterion="entropy")

clf = clf.fit(x_train, y_train)

# %%
y_pred = clf.predict(x_test)

# %%
print(f"Accuracy: {metrics.accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.7168196670297183

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(30,10), facecolor ='k')

a = tree.plot_tree(clf,

                   feature_names = col_names,

                   rounded = True,

                   filled = True,

                   fontsize=14)

plt.show()
